# %%
import requests

# %%
link1 = 'https://www.iate.obninsk.ru/'

# %%
resp = requests.get(link1)

# %%
resp.status_code
# Out:
# 200

# %%
with open('resp.html', 'w') as f:
    f.write(resp.text)

# %%
resp
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 resp
#
# File ~/Programming/PyCharm/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py:755, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     753 # if thread has a suspend flag, we suspend with a busy wait
#     754 if info.pydev_state == STATE_SUSPEND:
# --> 755     self.do_wait_suspend(thread, frame, event, arg)
#     756     # No need to reset frame.f_trace to keep the same trace function.
#     757     return self.trace_dispatch
#
# File ~/Programming/PyCharm/plugins/python/helpers/pydev/_pydevd_bundle/pydevd_frame.py:412, in PyDBFrame.do_wait_suspend(self, *args, **kwargs)
#     411 def do_wait_suspend(self, *args, **kwargs):
# --> 412     self._args[0].do_wait_suspend(*args, **kwargs)
#
# File ~/Programming/PyCharm/plugins/python/helpers/pydev/pydevd.py:1184, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1181         from_this_thread.append(frame_id)
#    1183 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1184     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File ~/Programming/PyCharm/plugins/python/helpers/pydev/pydevd.py:1199, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1196             self._call_mpl_hook()
#    1198         self.process_internal_commands()
# -> 1199         time.sleep(0.01)
#    1201 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1203 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
import pprint

# %%
pprint.pprint(resp.text[:10000])
# Out:
# ('<!DOCTYPE html>\n'
#  '<html lang="ru">\n'
#  '    <head>\n'
#  '        <meta charset="utf-8">\n'
#  '        <meta name="viewport" content="width=device-width, '
#  'initial-scale=1">\n'
#  '        <meta name="csrf-token" '
#  'content="fbLuoS7MfwiAAHNVH2bU2vftAuh82COP5BLl0Qv6">\n'
#  '\n'
#  '        <title>Официальный сайт ИАТЭ НИЯУ МИФИ</title>\n'
#  '\n'
#  '        <link rel="preload" as="style" '
#  'href="https://www.iate.obninsk.ru/build/assets/app-7c8c39ef.css" /><link '
#  'rel="modulepreload" '
#  'href="https://www.iate.obninsk.ru/build/assets/app-62ffa685.js" /><link '
#  'rel="stylesheet" '
#  'href="https://www.iate.obninsk.ru/build/assets/app-7c8c39ef.css" /><script '
#  'type="module" '
#  'src="https://www.iate.obninsk.ru/build/assets/app-62ffa685.js"></script>    '
#  '</head>\n'
#  '    <body x-data="{ themeName: sessionStorage.getItem(\'themeName\') !== '
#  'null ? sessionStorage.getItem(\'themeName\') : \'default\'  }"\n'
#  '          x-init="$watch(\'themeName\', (val) => '
#  'sessionStorage.setItem(\'themeName\', val))"\n'
#  '          :class="{\'theme-default\': themeName === \'default\', '
#  '\'theme-special\': themeName === \'special\' }"\n'
#  '\n'
#  '        \n'
#  '        class="font-roboto text-lg antialiased">\n'
#  '\n'
#  '                <div class="flex flex-col h-screen justify-between">\n'
#  '            \n'
#  '\n'
#  '            <!-- Page Header -->\n'
#  '\n'
#  '                <header class="bg-white dark:bg-gray-800">\n'
#  '                    <div class="max-w-screen-2xl mx-auto pt-4 pb-6 px-4 '
#  'sm:px-6 lg:px-8">\n'
#  '                        <div class="flex flex-wrap items-center">\n'
#  '    <div class="flex items-center pb-6 sm:pb-0 md:w-2/3 xl:w-3/4">\n'
#  '        <div class="pr-2">\n'
#  '            <a href="https://www.iate.obninsk.ru">\n'
#  '                <img '
#  'src="https://www.iate.obninsk.ru/build/assets/logo_inpe-10493a2c.svg" '
#  'alt="Логотип ИАТЭ" width="132" height="300" class="" >\n'
#  '            </a>\n'
#  '        </div>\n'
#  '        <div class="sm:text-2xl text-main-color border-l border-main-color '
#  'pl-2">\n'
#  '            <a href="https://www.iate.obninsk.ru">\n'
#  '                Обнинский институт<br>атомной энергетики НИЯУ МИФИ\n'
#  '            </a>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <div class="flex flex-col md:flex-row grow justify-between sm:ml-auto '
#  'md:w-1/3 xl:w-1/4">\n'
#  '        <div>\n'
#  '        </div>\n'
#  '        <div class="flex justify-between w-full mt-1 md:mt-0">\n'
#  '            <div class="w-full">\n'
#  '                <a class="block btn-secondary px-1 text-center sm:px-5 '
#  'md:px-2 lg:px-6" href="mailto:director@iate.obninsk.ru">Письмо '
#  'директору</a>\n'
#  '            </div>\n'
#  '            <div class="flex ml-3" itemprop="copy">\n'
#  '                <button @click="themeName = (themeName === \'default\' ? '
#  '\'special\' : \'default\')"\n'
#  '                        class="bg-special-icons self-center bg-no-repeat '
#  'w-[53px] h-[23px] hover:bg-[0_-23px]"></button>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '                        <nav x-data="{ open: false }" class="mt-3 '
#  'bg-main-color text-white">\n'
#  '    <!-- Primary Navigation Menu -->\n'
#  '    <div class="relative">\n'
#  '        <div class="flex justify-end h-12 md:justify-between">\n'
#  '            <ul class="flex z-50">\n'
#  '                                                    <li x-data="{ open1: '
#  'false }" x-on:mouseover="open1 = true"\n'
#  '                        x-on:mouseleave="open1 = false" class="hidden '
#  'relative uppercase sm:flex">\n'
#  '                        <a class="inline-flex items-center text-base '
#  'font-medium leading-5 text-white focus:outline-none focus:text-white '
#  'transition duration-150 ease-in-out hover:text-main-color-light px-4 sm:px-2 '
#  'sm:text-xs min-[900px]:text-[13px] min-[1165px]:text-base lg:px-4" '
#  'href="/sveden/common">\n'
#  '    О нас\n'
#  '</a>\n'
#  '                                                                        <ul '
#  'x-show="open1" class="absolute top-full left-0 block min-w-[20rem] '
#  'bg-gray-700 normal-case" x-cloak>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/sveden/common">\n'
#  '    Сведения об образовательной организации\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/sveden/employees">\n'
#  '    Руководство\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/2683">\n'
#  '    Учёный совет\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/sveden/struct">\n'
#  '    Подразделения\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/1666">\n'
#  '    Вакансии и конкурсы\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/1446">\n'
#  '    Взаимодействие со школами\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="#">\n'
#  '    Международное сотрудничество\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/19">\n'
#  '    Материальная база\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/44">\n'
#  '    Контакты и реквизиты\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/43">\n'
#  '    История\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/1332">\n'
#  '    Фирменный стиль\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                    </ul>\n'
#  '                                            </li>\n'
#  '                                    <li x-data="{ open4: false }" '
#  'x-on:mouseover="open4 = true"\n'
#  '                        x-on:mouseleave="open4 = false" class="hidden '
#  'relative uppercase sm:flex">\n'
#  '                        <a class="inline-flex items-center text-base '
#  'font-medium leading-5 text-white focus:outline-none focus:text-white '
#  'transition duration-150 ease-in-out hover:text-main-color-light px-4 sm:px-2 '
#  'sm:text-xs min-[900px]:text-[13px] min-[1165px]:text-base lg:px-4" '
#  'href="/node/2825">\n'
#  '    Абитуриентам\n'
#  '</a>\n'
#  '                                                                        <ul '
#  'x-show="open4" class="absolute top-full left-0 block min-w-[20rem] '
#  'bg-gray-700 normal-case" x-cloak>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/440">\n'
#  '    СПО: техникум\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="inline-flex items-center '
#  'text-base font-medium leading-5 text-white focus:outline-none '
#  'focus:text-white transition duration-150 ease-in-out w-full py-2 pl-4 pr-2 '
#  'font-normal text-white hover:text-gray-400" href="/node/2825">\n'
#  '    ВО: бакалавриат/специалитет\n'
#  '</a>\n'
#  '                                </li>\n'
#  '                                                            <li '
#  'class="w-full">\n'
#  '                                    <a class="')

# %%
search_resp = requests.get(link1+'search', params={'search':'экспертное'})
search_resp.url, search_resp.status_code
# Out:
# ('https://www.iate.obninsk.ru/search?search=%D1%8D%D0%BA%D1%81%D0%BF%D0%B5%D1%80%D1%82%D0%BD%D0%BE%D0%B5',
#  200)

# %%
with open('resp.html', 'w') as f:
    f.write(resp.text)

# %%
search_resp
# Out:
# <Response [200]>

# %%
link2 = 'https://timetable.iate.obninsk.ru/'

# %%
time_resp = requests.get(link2)
time_resp.url, time_resp.status_code
# Out:
# ('https://timetable.iate.obninsk.ru/', 200)

# %%
with open('resp.html', 'w') as f:
    f.write(time_resp.text)

# %%
time_resp.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="ru">\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1">\r\n\r\n    <meta name="csrf-token" content="tRFdNjIL6iXOcJSpfUm5pMMlq5kSlJDmw0IS3OVh">\r\n\r\n    <title>Главная | Расписание — ИАТЭ НИЯУ МИФИ</title>\r\n    \r\n    <link href="https://timetable.iate.obninsk.ru/css/bootstrap.min.css?diojMTrm" rel="stylesheet">\r\n    <link href="https://timetable.iate.obninsk.ru/fontawesome/css/fa-solid.min.css" rel="stylesheet">\r\n    <link href="https://timetable.iate.obninsk.ru/fontawesome/css/fontawesome.min.css" rel="stylesheet">\r\n    <link href="https://timetable.iate.obninsk.ru/css/style.css?diojMTrm" rel="stylesheet">\r\n      </head>\r\n  <body>\r\n    <header>\r\n      <div class="container">\r\n        <div class="row">\r\n          <div class="col-4 col-md-2 col-lg-2 align-self-center"><a href="http://www.iate.obninsk.ru"><img src="https://timetable.iate.obninsk.ru/img/logo_inpe_new.svg" class="img-fluid" alt="ИАТЭ НИЯУ МИФИ"></a></div>\r\n          <div class="col-8 col-md-10 col-lg-7 pl-0 align-self-center">\r\n            <div class="inpe-title">\r\n              <p>НАЦИОНАЛЬНЫЙ ИССЛЕДОВАТЕЛЬСКИЙ ЯДЕРНЫЙ УНИВЕРСИТЕТ «МИФИ» (НИЯУ МИФИ)</p>\r\n              <p>ОБНИНСКИЙ ИНСТИТУТ АТОМНОЙ ЭНЕРГЕТИКИ (ИАТЭ)</p>\r\n            </div>\r\n          </div>\r\n        </div>\r\n      </div>\r\n    </header>\r\n\r\n\r\n      <div class="main-content container">\r\n        <div class="row">\r\n          <div class="mx-4 mb-2 col-md-9 timetable-title">\r\n            <a class="logo" href="https://timetable.iate.obninsk.ru">\r\n              <img src="https://timetable.iate.obninsk.ru/img/table_logo_dark.svg" class="title-img" alt="" height="25" width="25" role="presentation" aria-hidden="true">\r\n              РАСПИСАНИЕ ЗАНЯТИЙ\r\n            </a>\r\n          </div>\r\n        </div>\r\n        <div class="row">\r\n          <div id="content" class="col-lg-9">\r\n                          <div class="card rounded-0 border-0">\r\n                                  <div class="p-4 card-body main-page">\r\n                                    <div class="row">\r\n                      <div class="col-md-12 col-lg-8">\r\n                        <h3>Весенний семестр 2023 — 2024 учебного года</h3>\r\n                        <form method="post" class="search-input-group">\r\n                          <div class="form-group">\r\n                            <div class="mb-2 input-group">\r\n                              <input type="search" class="form-control" name="name" value="">\r\n                              <div class="input-group-append">\r\n                                <span class="input-group-text rounded-0">\r\n                                  <button id="search-btn" type="submit">\r\n                                    <i class="fas fa-search"></i>\r\n                                  </button>  \r\n                                </span>\r\n                              </div>\r\n                            </div>\r\n                            <div class="form-row">\r\n                              <div class="form-group col-6 col-sm-2">\r\n                                <label>\r\n                                  <input type="radio" value="group" name="searchtype" checked>\r\n                                  группа\r\n                                </label> \r\n                              </div>\r\n                              <div class="form-group col-6  col-sm-3 ">\r\n                                <label>\r\n                                  <input type="radio" value="room" name="searchtype">\r\n                                  аудитория\r\n                                </label>\r\n                              </div>\r\n                              <div class="form-group col-12 col-sm-4">\r\n                                <label>\r\n              ...

# %%
text = time_resp.text.replace('\r', '').split('\n')
pprint.pp(text)
# Out:
# ['<!DOCTYPE html>',
#  '<html lang="ru">',
#  '  <head>',
#  '    <meta charset="utf-8">',
#  '    <meta http-equiv="X-UA-Compatible" content="IE=edge">',
#  '    <meta name="viewport" content="width=device-width, initial-scale=1">',
#  '',
#  '    <meta name="csrf-token" '
#  'content="tRFdNjIL6iXOcJSpfUm5pMMlq5kSlJDmw0IS3OVh">',
#  '',
#  '    <title>Главная | Расписание — ИАТЭ НИЯУ МИФИ</title>',
#  '    ',
#  '    <link '
#  'href="https://timetable.iate.obninsk.ru/css/bootstrap.min.css?diojMTrm" '
#  'rel="stylesheet">',
#  '    <link '
#  'href="https://timetable.iate.obninsk.ru/fontawesome/css/fa-solid.min.css" '
#  'rel="stylesheet">',
#  '    <link '
#  'href="https://timetable.iate.obninsk.ru/fontawesome/css/fontawesome.min.css" '
#  'rel="stylesheet">',
#  '    <link href="https://timetable.iate.obninsk.ru/css/style.css?diojMTrm" '
#  'rel="stylesheet">',
#  '      </head>',
#  '  <body>',
#  '    <header>',
#  '      <div class="container">',
#  '        <div class="row">',
#  '          <div class="col-4 col-md-2 col-lg-2 align-self-center"><a '
#  'href="http://www.iate.obninsk.ru"><img '
#  'src="https://timetable.iate.obninsk.ru/img/logo_inpe_new.svg" '
#  'class="img-fluid" alt="ИАТЭ НИЯУ МИФИ"></a></div>',
#  '          <div class="col-8 col-md-10 col-lg-7 pl-0 align-self-center">',
#  '            <div class="inpe-title">',
#  '              <p>НАЦИОНАЛЬНЫЙ ИССЛЕДОВАТЕЛЬСКИЙ ЯДЕРНЫЙ УНИВЕРСИТЕТ «МИФИ» '
#  '(НИЯУ МИФИ)</p>',
#  '              <p>ОБНИНСКИЙ ИНСТИТУТ АТОМНОЙ ЭНЕРГЕТИКИ (ИАТЭ)</p>',
#  '            </div>',
#  '          </div>',
#  '        </div>',
#  '      </div>',
#  '    </header>',
#  '',
#  '',
#  '      <div class="main-content container">',
#  '        <div class="row">',
#  '          <div class="mx-4 mb-2 col-md-9 timetable-title">',
#  '            <a class="logo" href="https://timetable.iate.obninsk.ru">',
#  '              <img '
#  'src="https://timetable.iate.obninsk.ru/img/table_logo_dark.svg" '
#  'class="title-img" alt="" height="25" width="25" role="presentation" '
#  'aria-hidden="true">',
#  '              РАСПИСАНИЕ ЗАНЯТИЙ',
#  '            </a>',
#  '          </div>',
#  '        </div>',
#  '        <div class="row">',
#  '          <div id="content" class="col-lg-9">',
#  '                          <div class="card rounded-0 border-0">',
#  '                                  <div class="p-4 card-body main-page">',
#  '                                    <div class="row">',
#  '                      <div class="col-md-12 col-lg-8">',
#  '                        <h3>Весенний семестр 2023 — 2024 учебного года</h3>',
#  '                        <form method="post" class="search-input-group">',
#  '                          <div class="form-group">',
#  '                            <div class="mb-2 input-group">',
#  '                              <input type="search" class="form-control" '
#  'name="name" value="">',
#  '                              <div class="input-group-append">',
#  '                                <span class="input-group-text rounded-0">',
#  '                                  <button id="search-btn" type="submit">',
#  '                                    <i class="fas fa-search"></i>',
#  '                                  </button>  ',
#  '                                </span>',
#  '                              </div>',
#  '                            </div>',
#  '                            <div class="form-row">',
#  '                              <div class="form-group col-6 col-sm-2">',
#  '                                <label>',
#  '                                  <input type="radio" value="group" '
#  'name="searchtype" checked>',
#  '                                  группа',
#  '                                </label> ',
#  '                              </div>',
#  '                              <div class="form-group col-6  col-sm-3 ">',
#  '                                <label>',
#  '                                  <input type="radio" value="room" '
#  'name="searchtype">',
#  '                                  аудитория',
#  '                                </label>',
#  '                              </div>',
#  '                              <div class="form-group col-12 col-sm-4">',
#  '                                <label>',
#  '                                  <input type="radio" value="teacher" '
#  'name="searchtype">',
#  '                                  преподаватель',
#  '                                </label>',
#  '                              </div>',
#  '                            </div>',
#  '                          </div>',
#  '                        </form>',
#  '                      </div>',
#  '                      <div class="mt-2 col-lg-4 text-center d-none '
#  'd-lg-block d-xl-block">',
#  '                        <img '
#  'src="https://timetable.iate.obninsk.ru/img/table_logo_light.svg" alt="" '
#  'height="130" width="130" role="presentation" aria-hidden="true">',
#  '                      </div>',
#  '                                                                    <div '
#  'class="col-lg-12 pt-0 pt-lg-3 main-notice">',
#  '                          <h2>&nbsp;</h2>',
#  '',
#  '<p>С 15.04.2024&nbsp;по 20.04.2024&nbsp;- 11&nbsp;неделя (верхняя/ '
#  'нечетная)</p>',
#  '',
#  '<p>&nbsp;</p>',
#  '',
#  '<p>С 08.04.2024&nbsp;по 13.04.2024&nbsp;- 10&nbsp;неделя (нижняя/ '
#  'четная)</p>',
#  '',
#  '<p>&nbsp;</p>',
#  '',
#  '<p><strong>ВНИМАНИЕ! В расписании занятий возможны изменения.</strong></p>',
#  '',
#  '<p>&nbsp;</p>',
#  '',
#  '<p>Информация для организации обучения с использованием дистанционных '
#  'образовательных технологий (<strong>ДОТ</strong>) приводится в&nbsp;разделе '
#  '&quot;<strong>Организация обучения с использованием '
#  'ДОТ&quot;</strong>&nbsp;(<a '
#  'href="http://timetable.iate.obninsk.ru/node/26">ПЕРЕЙТИ</a>) .&nbsp;</p>',
#  '',
#  '<p>&nbsp;</p>',
#  '                        </div>',
#  '                                          </div>',
#  '                    <div class="found-groups w-100">',
#  '                                                                        <div '
#  'class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">1 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/407">АУТ-А23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/414">АЭС1-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/415">АЭС2-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/416">АЭС3-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/413">АЭС-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/410">БИЗ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/495">БИО-А23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/426">БИО-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/427">БИО-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/472">ГМУ-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/434">ИВТ1-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/435">ИВТ2-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/433">ИВТ-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/437">ИС1-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/438">ИС2-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/436">ИС-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/442">ЛД1-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/469">ЛД1-С23и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/443">ЛД2-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/470">ЛД2-С23и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/444">ЛД3-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/471">ЛД3-С23и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/445">ЛД4-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/446">ЛД5-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/447">ЛД6-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/448">ЛД7-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/449">ЛД8-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/428">М2-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/439">М-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/411">МЕН-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/473">МЕН-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/440">М-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/441">МТМ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/409">МТМ-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/429">МФ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/418">РБ-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/417">Р-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/419">ТД-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/420">ТД-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/494">УНХ-А23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/430">ХИМ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/431">ХФМ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/432">ХФМ-М23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/421">Э-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/422">ЭиА-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/412">ЭКН-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/423">ЯРМ-С23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/424">ЯФТ-Б23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/425">ЯЭТ-Б23и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/408">ЯЭУ-А23</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">2 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/450">АУТ-А22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/358">АЭС1-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/359">АЭС2-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/382">БИЗ-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/368">БИО-А22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/348">БИО-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/375">ИВТ1-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/376">ИВТ2-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/378">ИС1-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/379">ИС2-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/387">ЛД1-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/401">ЛД1-С22и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/388">ЛД2-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/402">ЛД2-С22и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/389">ЛД3-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/390">ЛД4-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/391">ЛД5-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/392">ЛД6-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/393">ЛД7-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/394">ЛД8-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/451">М-А22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/380">М-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/384">МЕН-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/454">МН-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/345">МТМ1-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/346">МТМ2-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/459">МФ1-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/452">ПМФ-А22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/362">ТД-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/347">ТФ-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/453">УНХ-А22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/352">ХИМ-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/460">ХФМ1-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/461">ХФМ2-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/455">ЭиА1-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/456">ЭиА2-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/386">ЭКН-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/457">ЯРМ1-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/458">ЯРМ2-С22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/366">ЯФТ-Б22</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/400">ЯЭТ-Б22и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/373">ЯЭУ-А22</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">3 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/295">АЭС1-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/296">АЭС2-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/266">БИЗ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/318">БИО-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/271">БИО-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/337">ИВТ1-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/338">ИВТ2-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/339">ИС1-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/340">ИС2-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/301">ЛД1-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/320">ЛД1-С21и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/302">ЛД2-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/321">ЛД2-С21и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/303">ЛД3-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/322">ЛД3-С21и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/304">ЛД4-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/305">ЛД5-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/306">ЛД6-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/462">М-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/265">М-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/267">МЕН-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/464">МН-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/269">МТМ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/260">МФ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/336">ПМФ-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/465">РБ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/315">САУ-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/272">ТД-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/270">ТФ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/463">УОС-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/312">ФКС-А21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/261">ХИМ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/262">ХФМ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/466">Э-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/297">ЭиА-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/268">ЭКН-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/298">ЯРМ-С21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/273">ЯФТ-Б21</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/275">ЯЭТ-Б21и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/317">ЯЭУ-А21</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">4 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/299">АЭС1-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/300">АЭС2-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/176">БИЗ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/192">БИО-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/173">ИВТ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/467">ИС1-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/468">ИС2-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/227">ЛД1-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/228">ЛД2-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/229">ЛД3-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/230">ЛД4-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/231">ЛД5-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/232">ЛД6-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/233">ЛД7-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/309">ЛД-С20и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/175">М-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/190">МТМ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/170">МФ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/341">РБ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/342">РБ-Б20и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/193">ТД-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/191">ТФ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/171">ХИМ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/172">ХФМ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/343">Э-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/194">ЭиА-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/177">ЭКН-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/195">ЯРМ-С20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/196">ЯФТ-Б20</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/198">ЯЭТ-Б20и</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">5 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/199">АЭС-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/44">ЛД1-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/45">ЛД1-С19и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/46">ЛД2-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/251">ЛД2-С19и</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/47">ЛД3-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/48">ЛД4-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/234">ЛД5-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/235">ЛД6-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/201">ЭиА-С19</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/202">ЯРМ-С19</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name">6 курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/81">ЛД1-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/258">ЛД1-С18И</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/82">ЛД2-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/259">ЛД2-С18И</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/83">ЛД3-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/84">ЛД4-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/238">ЛД5-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/239">ЛД6-С18</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/240">ЛД7-С18</a></div> ',
#  '                                                    </div>',
#  '                                                  <div class="row">',
#  '                            <div class="col-md-12 group-name-block">',
#  '                                <span class="group-name"> курс</span>',
#  '                            </div>',
#  '                          </div>',
#  '                          <div class="d-flex justify-content-between '
#  'flex-wrap">',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/496">ПФ1-23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/497">ПФ2-23</a></div> ',
#  '                                                      <div '
#  'class="found-group"><a '
#  'href="https://timetable.iate.obninsk.ru/group/498">ПФ3-23</a></div> ',
#  '                                                    </div>',
#  '                                                                  </div>',
#  '                    <div class="search-no-results" style="display: none;">',
#  '                      <i>По вашему запросу ничего не найдено.</i>',
#  '                    </div>',
#  '                  </div>',
#  '              </div>',
#  '                        ',
#  '            ',
#  '    ',
#  '',
#  '',
#  '          </div>',
#  '          <aside class="pl-lg-0 mt-3 mt-lg-0 col-md-12 col-lg-3 right-menu">',
#  '            <ul>',
#  '              <li>',
#  '                <a href="https://timetable.iate.obninsk.ru">',
#  '                  <div class="rectangle-marker">',
#  '                    <div class="link-content">Расписание занятий</div>',
#  '                  </div>',
#  '                </a>',
#  '              </li>',
#  '                                             <li >',
#  '                  <a href="/node/32">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">ВАЖНО К СЕССИИ!!! ПЕРЕСДАЧИ '
#  'текущих задолженностей в осеннем семестре 2023-2024 учебного года</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/10">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">РАСПИСАНИЕ ЗАНЯТИЙ, осень '
#  '2023-2024, Медицинский факультет 4 - 6 курсы</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li >',
#  '                  <a href="/node/13">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">РАСПИСАНИЕ ЗАНЯТИЙ на '
#  '2023-2024 учебный год, очно-заочная и заочная форма обучения</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/7">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">РАСПИСАНИЕ ЗАЧЕТОВ</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li >',
#  '                  <a href="/node/8">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">РАСПИСАНИЕ ЭКЗАМЕНОВ</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/27">',
#  '                    <div class="rectangle-marker">',
#  '                      <div '
#  'class="link-content">ПЕРЕСДАЧИ!!!                                     '
#  'Расписание повторных промежуточных аттестаций</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li >',
#  '                  <a href="/node/28">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">КОМИССИОННЫЕ ПЕРЕСДАЧИ!!! '
#  'Расписание вторых повторных промежуточных аттестаций</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/22">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">ПЕРЕСДАЧИ!!! Расписание '
#  'повторных промежуточных аттестаций в группах медицинского факультета '
#  '(иностранные студенты)</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li >',
#  '                  <a href="/node/21">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">КОМИССИОННЫЕ ПЕРЕСДАЧИ!!! '
#  'Расписание вторых повторных промежуточных аттестаций в группах медицинского '
#  'факультета (иностранные студенты)</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/9">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">ГРАФИК ПРОВЕДЕНИЯ '
#  'ГОСУДАРСТВЕННОЙ ИТОГОВОЙ АТТЕСТАЦИИ в 2023-2024 учебном году</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                            <li >',
#  '                  <a href="/node/4">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">ИНФОРМАЦИЯ ОБ '
#  'ОБРАЗОВАТЕЛЬНЫХ ПРОГРАММАХ (учебные планы, календарные учебные графики и '
#  'т.д.) на 2023-2024 учебный год</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                                                            <li '
#  'class="menu-divider"></li>',
#  '                                                           <li>',
#  '                  <a href="https://timetable.iate.obninsk.ru/login">',
#  '                    <div class="rectangle-marker">',
#  '                      <div class="link-content">Войти</div>',
#  '                    </div>',
#  '                  </a>',
#  '                </li>',
#  '                          </ul>',
#  '          </aside>',
#  '        </div>',
#  '      </div>',
#  '    ',
#  '    ',
#  '    ',
#  '',
#  '',
#  '    <footer>',
#  '      <div class="container">',
#  '        <div class="row">',
#  '          <div class="col-md-9">',
#  '              <div class="px-2 pl-md-4 pr-md-0">©2024 НАЦИОНАЛЬНЫЙ '
#  'ИССЛЕДОВАТЕЛЬСКИЙ ЯДЕРНЫЙ УНИВЕРСИТЕТ «МИФИ» (НИЯУ МИФИ)<br>ОБНИНСКИЙ '
#  'ИНСТИТУТ АТОМНОЙ ЭНЕРГЕТИКИ (ИАТЭ)</div>',
#  '          </div>',
#  '        </div>',
#  '      </div>',
#  '    </footer>',
#  '        ',
#  '    <script '
#  'src="https://timetable.iate.obninsk.ru/js/jquery.min.js?diojMTrm"></script>',
#  '    <script '
#  'src="https://timetable.iate.obninsk.ru/js/popper.min.js?diojMTrm"></script>',
#  '    <script '
#  'src="https://timetable.iate.obninsk.ru/js/bootstrap.min.js?diojMTrm"></script>',
#  '    <script type="text/javascript">',
#  '        const COURSE_STR         = "курс";',
#  '        const BUILDING_STR       = "корпус";',
#  '        const BUILDING_OTHER_STR = "Другой";',
#  '        const GROUP_URL   = "https://timetable.iate.obninsk.ru/group";',
#  '        const ROOM_URL    = "https://timetable.iate.obninsk.ru/room";',
#  '        const TEACHER_URL = "https://timetable.iate.obninsk.ru/teacher";',
#  '    </script>',
#  '    ',
#  '        <script '
#  'src="https://timetable.iate.obninsk.ru/js/custom.js?diojMTrm"></script>',
#  '    ',
#  '      </body>',
#  '</html>',
#  '']

# %%
ids = []
for i in range(len(text)):
    if '<div class="found-group">' in text[i]:
        l = text[i].replace(' ', '').split('"')
        group_id = l[-2].split('/')[-1]
        ids.append(int(group_id))

# %%
len(ids)
# Out:
# 185

# %%
link3 = 'https://timetable.iate.obninsk.ru/group/'
time_resp = requests.get(link3+str(ids[54]))
with open('resp.html', 'w') as f:
    f.write(time_resp.text)
